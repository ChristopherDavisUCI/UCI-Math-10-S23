# %% [markdown]
# # Worksheet 16
#
# Author (use your full name): **BLANK**
#
# **This is the only worksheet that must be done individually, not in a group**
#
# The goal of this homework is to get you thinking about the Course Project.  Detailed instructions for the course project are in the [course notes](https://christopherdavisuci.github.io/UCI-Math-10-F22/Proj/CourseProject.html).

# %% [markdown]
# ## Question 1
#
# Look through the student projects from [Winter 22](https://christopherdavisuci.github.io/UCI-Math-10-W22/Proj/StudentProjects.html) and from [Spring 22](https://christopherdavisuci.github.io/UCI-Math-10-S22/Proj/StudentProjects.html).  What is an example of one of these projects that you like?  In a markdown cell, give a link to that project and explain in about two sentences what you like about it.

# %% [markdown]
# ## Question 2
#
# Find a potential dataset to use for your project, upload it to this Deepnote project, and then import it to this notebook using pandas.  In a markdown cell, briefly explain what this dataset contains and say where it comes from.  (It's fine to later choose a different dataset for your actual course project.)

# %% [markdown]
# ## Question 3
#
# Do you have an idea for the focus of your project?  Is there a specific question you want to investigate related to the dataset?  (It's very fine to change your mind later.)

# %% [markdown]
# ## Question 4
#
# What are you considering for the “Extra” portion of the project?  (Again, it's fine to change your mind later.  The point of these questions is to get you thinking about these decisions early.)

# %% [markdown]
# ## Question 5
#
# Do you already know any References/Tutorials you are planning to use? If so, list them here.

# %% [markdown]
# ## Question 6
#
# Do you have any questions for us regarding the project?

# %% [markdown]
# ## Submission
#
# Using the Share button at the top right, **enable Comment access level** for anyone with the link. Then submit that link on Canvas.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=86d5b21b-fa31-4baf-ba8d-69d3efd1a2ff' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
